# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
import quandl

# %%
Intel = quandl.get("EOD/INTC", authtoken="pujeGgzT8PLCJnNsf3zL")
Intel
# Out:
#               Open     High      Low  Close      Volume  Dividend  Split  \
# Date
# 1980-03-17  62.500  63.5000  62.5000  62.50     56900.0       0.0    1.0
# 1980-03-18  62.500  63.0000  62.0000  62.00     88900.0       0.0    1.0
# 1980-03-19  63.500  64.5000  63.5000  63.50     96400.0       0.0    1.0
# 1980-03-20  63.500  64.2500  63.2500  63.25     58200.0       0.0    1.0
# 1980-03-21  62.000  62.0000  61.0000  61.00     63400.0       0.0    1.0
# 1980-03-24  60.750  60.7500  59.7500  59.75     46700.0       0.0    1.0
# 1980-03-25  60.000  61.0000  60.0000  60.00     59100.0       0.0    1.0
# 1980-03-26  60.000  60.5000  59.5000  59.50     84700.0       0.0    1.0
# 1980-03-27  58.500  58.5000  57.5000  57.50    140200.0       0.0    1.0
# 1980-03-28  59.750  60.7500  59.7500  59.75    104700.0       0.0    1.0
# 1980-03-31  61.750  62.7500  61.7500  61.75     46900.0       0.0    1.0
# 1980-04-01  62.000  63.0000  62.0000  62.00     42600.0       0.0    1.0
# ...

# %%
Intel.head(10)
# Out:
#              Open   High    Low  Close    Volume  Dividend  Split  Adj_Open  \
# Date
# 1980-03-17  62.50  63.50  62.50  62.50   56900.0       0.0    1.0  0.212218
# 1980-03-18  62.50  63.00  62.00  62.00   88900.0       0.0    1.0  0.212218
# 1980-03-19  63.50  64.50  63.50  63.50   96400.0       0.0    1.0  0.215614
# 1980-03-20  63.50  64.25  63.25  63.25   58200.0       0.0    1.0  0.215614
# 1980-03-21  62.00  62.00  61.00  61.00   63400.0       0.0    1.0  0.210520
# 1980-03-24  60.75  60.75  59.75  59.75   46700.0       0.0    1.0  0.206276
# 1980-03-25  60.00  61.00  60.00  60.00   59100.0       0.0    1.0  0.203729
# 1980-03-26  60.00  60.50  59.50  59.50   84700.0       0.0    1.0  0.203729
# 1980-03-27  58.50  58.50  57.50  57.50  140200.0       0.0    1.0  0.198636
# 1980-03-28  59.75  60.75  59.75  59.75  104700.0       0.0    1.0  0.202880
#
#             Adj_High   Adj_Low  Adj_Close  Adj_Volume
# Date
# 1980-03-17  0.215614  0.212218   0.212218  10924800.0
# ...

# %%
Intel.tail(10)
# Out:
#              Open   High    Low  Close      Volume  Dividend  Split  Adj_Open  \
# Date
# 2018-08-15  47.78  48.00  46.90  47.46  26739870.0       0.0    1.0     47.78
# 2018-08-16  47.75  47.95  47.05  47.17  24358040.0       0.0    1.0     47.75
# 2018-08-17  47.00  47.39  46.33  47.10  26381992.0       0.0    1.0     47.00
# 2018-08-20  47.05  47.12  46.19  46.50  24334042.0       0.0    1.0     47.05
# 2018-08-21  46.66  47.85  46.64  47.62  19254336.0       0.0    1.0     46.66
# 2018-08-22  47.25  47.35  46.92  47.05  23182485.0       0.0    1.0     47.25
# 2018-08-23  46.86  47.17  46.71  46.98  31343206.0       0.0    1.0     46.86
# 2018-08-24  47.29  47.89  47.08  47.66  18214708.0       0.0    1.0     47.29
# 2018-08-27  48.00  48.39  47.63  48.35  17170257.0       0.0    1.0     48.00
# 2018-08-28  48.55  48.79  48.31  48.57  13472427.0       0.0    1.0     48.55
#
#             Adj_High  Adj_Low  Adj_Close  Adj_Volume
# Date
# ...

# %%
Intel2 = pd.DataFrame(Intel)

# %%
Intel3 = del Intel2['Open']
Intel3
# Out:
#   File "<ipython-input-6-8436acafb4ae>", line 1
#     Intel3 = del Intel2['Open']
#                ^
# SyntaxError: invalid syntax

# %%
info = Intel['Close']
info
# Out:
# Date
# 1980-03-17    62.50
# 1980-03-18    62.00
# 1980-03-19    63.50
# 1980-03-20    63.25
# 1980-03-21    61.00
# 1980-03-24    59.75
# 1980-03-25    60.00
# 1980-03-26    59.50
# 1980-03-27    57.50
# 1980-03-28    59.75
# 1980-03-31    61.75
# 1980-04-01    62.00
# 1980-04-02    62.50
# 1980-04-03    61.25
# 1980-04-07    59.75
# 1980-04-08    60.00
# 1980-04-09    58.75
# 1980-04-10    58.50
# 1980-04-11    58.50
# 1980-04-14    59.00
# 1980-04-15    58.25
# 1980-04-16    56.00
# 1980-04-17    55.00
# 1980-04-18    55.75
# 1980-04-21    55.25
# 1980-04-22    57.75
# 1980-04-23    61.25
# 1980-04-24    61.50
# 1980-04-25    60.50
# 1980-04-28    60.00
#               ...
# 2018-07-18    51.72
# 2018-07-19    51.98
# 2018-07-20    51.91
# 2018-07-23    52.31
# 2018-07-24    52.18
# 2018-07-25    52.43
# 2018-07-26    52.16
# 2018-07-27    47.68
# 2018-07-30    47.69
# 2018-07-31    48.10
# 2018-08-01    48.81
# 2018-08-02    49.48
# 2018-08-03    49.63
# 2018-08-06    49.30
# ...

# %%
info
# Out:
# Date
# 1980-03-17    62.50
# 1980-03-18    62.00
# 1980-03-19    63.50
# 1980-03-20    63.25
# 1980-03-21    61.00
# 1980-03-24    59.75
# 1980-03-25    60.00
# 1980-03-26    59.50
# 1980-03-27    57.50
# 1980-03-28    59.75
# 1980-03-31    61.75
# 1980-04-01    62.00
# 1980-04-02    62.50
# 1980-04-03    61.25
# 1980-04-07    59.75
# 1980-04-08    60.00
# 1980-04-09    58.75
# 1980-04-10    58.50
# 1980-04-11    58.50
# 1980-04-14    59.00
# 1980-04-15    58.25
# 1980-04-16    56.00
# 1980-04-17    55.00
# 1980-04-18    55.75
# 1980-04-21    55.25
# 1980-04-22    57.75
# 1980-04-23    61.25
# 1980-04-24    61.50
# 1980-04-25    60.50
# 1980-04-28    60.00
#               ...
# 2018-07-18    51.72
# 2018-07-19    51.98
# 2018-07-20    51.91
# 2018-07-23    52.31
# 2018-07-24    52.18
# 2018-07-25    52.43
# 2018-07-26    52.16
# 2018-07-27    47.68
# 2018-07-30    47.69
# 2018-07-31    48.10
# 2018-08-01    48.81
# 2018-08-02    49.48
# 2018-08-03    49.63
# 2018-08-06    49.30
# ...

# %%
INTc = pd.DataFrame(info)
INTc
# Out:
#             Close
# Date
# 1980-03-17  62.50
# 1980-03-18  62.00
# 1980-03-19  63.50
# 1980-03-20  63.25
# 1980-03-21  61.00
# 1980-03-24  59.75
# 1980-03-25  60.00
# 1980-03-26  59.50
# 1980-03-27  57.50
# 1980-03-28  59.75
# 1980-03-31  61.75
# 1980-04-01  62.00
# 1980-04-02  62.50
# 1980-04-03  61.25
# 1980-04-07  59.75
# 1980-04-08  60.00
# 1980-04-09  58.75
# 1980-04-10  58.50
# 1980-04-11  58.50
# 1980-04-14  59.00
# 1980-04-15  58.25
# 1980-04-16  56.00
# 1980-04-17  55.00
# 1980-04-18  55.75
# 1980-04-21  55.25
# 1980-04-22  57.75
# 1980-04-23  61.25
# 1980-04-24  61.50
# 1980-04-25  60.50
# 1980-04-28  60.00
# ...           ...
# 2018-07-18  51.72
# 2018-07-19  51.98
# 2018-07-20  51.91
# 2018-07-23  52.31
# 2018-07-24  52.18
# 2018-07-25  52.43
# 2018-07-26  52.16
# 2018-07-27  47.68
# 2018-07-30  47.69
# 2018-07-31  48.10
# 2018-08-01  48.81
# 2018-08-02  49.48
# 2018-08-03  49.63
# 2018-08-06  49.30
# 2018-08-07  49.70
# 2018-08-08  49.96
# 2018-08-09  50.14
# ...

# %%
plt.figure(figsize = (15, 10))
plt.grid(True)
plt.plot(INTc['Close'], label = 'INTC', color = 'b')
plt.ylabel('Stock Price')
plt.xlabel('Year')
plt.title('Average Closing Price of Intel Corp. Since IPO')
plt.legend(loc = 1)
plt.show()

# %%
from datetime import datetime as dt

# %%
plt.figure(figsize = (15, 6))
plt.plot(INTc['Close'])
plt.title('Average Closing Price of INTEL CORP. Since IPO')
plt.xlabel('Year')
plt.ylabel('Stock Price')
plt.legend(loc = 1)
plt.show()

# %%
plt.figure(figsize = (15, 6))
plt.scatter(x = INTc['Close'].index, y = INTc['Close'], color = 'g')
plt.title('Average Closing Price of INTEL CORP. Since IPO')
plt.xlabel('Year')
plt.ylabel('Stock Price')
plt.legend(loc = 1)
plt.show()
