# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
import quandl

# %%
quandl.ApiConfig.api_key = "YOURAPIKEY"

# %%
Nike = quandl.get("EOD/NKE", authtoken="pujeGgzT8PLCJnNsf3zL")
Nike
# Out:
#              Open     High     Low  Close     Volume  Dividend  Split  \
# Date
# 1980-12-02  11.50  11.7500  11.500  11.50   786800.0       0.0    1.0
# 1980-12-03  11.38  11.3800  11.250  11.25   196700.0       0.0    1.0
# 1980-12-04  11.62  11.7500  11.620  11.62   177300.0       0.0    1.0
# 1980-12-05  11.25  11.2500  11.000  11.00    59300.0       0.0    1.0
# 1980-12-08  10.50  10.5000  10.380  10.38    42300.0       0.0    1.0
# 1980-12-09  10.38  10.3800  10.130  10.13    45500.0       0.0    1.0
# 1980-12-10   9.87   9.8700   9.500   9.50    45900.0       0.0    1.0
# 1980-12-11   9.25   9.2500   9.000   9.00    42500.0       0.0    1.0
# 1980-12-12   9.38   9.5000   9.380   9.38    63700.0       0.0    1.0
# 1980-12-15   9.75   9.8700   9.750   9.75    51900.0       0.0    1.0
# 1980-12-16   9.75   9.7500   9.500   9.50    51800.0       0.0    1.0
# 1980-12-17   9.38   9.3800   9.130   9.13    36500.0       0.0    1.0
# ...

# %%
Nike.df = pd.DataFrame(Nike)
Nike.df
# Out:
#              Open     High     Low  Close     Volume  Dividend  Split  \
# Date
# 1980-12-02  11.50  11.7500  11.500  11.50   786800.0       0.0    1.0
# 1980-12-03  11.38  11.3800  11.250  11.25   196700.0       0.0    1.0
# 1980-12-04  11.62  11.7500  11.620  11.62   177300.0       0.0    1.0
# 1980-12-05  11.25  11.2500  11.000  11.00    59300.0       0.0    1.0
# 1980-12-08  10.50  10.5000  10.380  10.38    42300.0       0.0    1.0
# 1980-12-09  10.38  10.3800  10.130  10.13    45500.0       0.0    1.0
# 1980-12-10   9.87   9.8700   9.500   9.50    45900.0       0.0    1.0
# 1980-12-11   9.25   9.2500   9.000   9.00    42500.0       0.0    1.0
# 1980-12-12   9.38   9.5000   9.380   9.38    63700.0       0.0    1.0
# 1980-12-15   9.75   9.8700   9.750   9.75    51900.0       0.0    1.0
# 1980-12-16   9.75   9.7500   9.500   9.50    51800.0       0.0    1.0
# 1980-12-17   9.38   9.3800   9.130   9.13    36500.0       0.0    1.0
# ...

# %%
Nike.df.iloc[:,:4]
# Out:
#              Open     High     Low  Close
# Date
# 1980-12-02  11.50  11.7500  11.500  11.50
# 1980-12-03  11.38  11.3800  11.250  11.25
# 1980-12-04  11.62  11.7500  11.620  11.62
# 1980-12-05  11.25  11.2500  11.000  11.00
# 1980-12-08  10.50  10.5000  10.380  10.38
# 1980-12-09  10.38  10.3800  10.130  10.13
# 1980-12-10   9.87   9.8700   9.500   9.50
# 1980-12-11   9.25   9.2500   9.000   9.00
# 1980-12-12   9.38   9.5000   9.380   9.38
# 1980-12-15   9.75   9.8700   9.750   9.75
# 1980-12-16   9.75   9.7500   9.500   9.50
# 1980-12-17   9.38   9.3800   9.130   9.13
# 1980-12-18   9.38   9.6200   9.380   9.38
# 1980-12-19   9.75   9.8700   9.750   9.75
# 1980-12-22   9.75  10.0000   9.750   9.75
# 1980-12-23  10.00  10.2500  10.000  10.00
# 1980-12-24  10.38  10.6200  10.380  10.38
# 1980-12-26  10.50  10.7500  10.500  10.50
# 1980-12-29  10.50  10.6200  10.380  10.38
# 1980-12-30  10.62  10.7500  10.620  10.62
# 1980-12-31  10.62  10.7500  10.500  10.50
# ...

# %%
Stock = Nike.df['Close']
Stock
# Out:
# Date
# 1980-12-02    11.50
# 1980-12-03    11.25
# 1980-12-04    11.62
# 1980-12-05    11.00
# 1980-12-08    10.38
# 1980-12-09    10.13
# 1980-12-10     9.50
# 1980-12-11     9.00
# 1980-12-12     9.38
# 1980-12-15     9.75
# 1980-12-16     9.50
# 1980-12-17     9.13
# 1980-12-18     9.38
# 1980-12-19     9.75
# 1980-12-22     9.75
# 1980-12-23    10.00
# 1980-12-24    10.38
# 1980-12-26    10.50
# 1980-12-29    10.38
# 1980-12-30    10.62
# 1980-12-31    10.50
# 1981-01-02    10.75
# 1981-01-05    11.19
# 1981-01-06    11.25
# 1981-01-07    10.62
# 1981-01-08    10.38
# 1981-01-09    10.25
# 1981-01-12    10.38
# 1981-01-13    10.62
# 1981-01-14    11.00
#               ...
# 2018-07-18    76.59
# 2018-07-19    76.95
# 2018-07-20    76.96
# 2018-07-23    76.59
# 2018-07-24    75.53
# 2018-07-25    77.16
# 2018-07-26    78.15
# 2018-07-27    76.89
# 2018-07-30    75.96
# 2018-07-31    76.91
# 2018-08-01    77.54
# 2018-08-02    78.65
# 2018-08-03    78.74
# 2018-08-06    79.51
# ...

# %%
Nike.df.head(10)
# Out:
#              Open   High    Low  Close    Volume  Dividend  Split  Adj_Open  \
# Date
# 1980-12-02  11.50  11.75  11.50  11.50  786800.0       0.0    1.0  0.060812
# 1980-12-03  11.38  11.38  11.25  11.25  196700.0       0.0    1.0  0.060177
# 1980-12-04  11.62  11.75  11.62  11.62  177300.0       0.0    1.0  0.061446
# 1980-12-05  11.25  11.25  11.00  11.00   59300.0       0.0    1.0  0.059490
# 1980-12-08  10.50  10.50  10.38  10.38   42300.0       0.0    1.0  0.055524
# 1980-12-09  10.38  10.38  10.13  10.13   45500.0       0.0    1.0  0.054889
# 1980-12-10   9.87   9.87   9.50   9.50   45900.0       0.0    1.0  0.052192
# 1980-12-11   9.25   9.25   9.00   9.00   42500.0       0.0    1.0  0.048914
# 1980-12-12   9.38   9.50   9.38   9.38   63700.0       0.0    1.0  0.049601
# 1980-12-15   9.75   9.87   9.75   9.75   51900.0       0.0    1.0  0.051558
#
#             Adj_High   Adj_Low  Adj_Close   Adj_Volume
# Date
# 1980-12-02  0.062134  0.060812   0.060812  100710400.0
# ...

# %%
Nike.df.tail(10)
# Out:
#              Open     High    Low  Close     Volume  Dividend  Split  \
# Date
# 2018-08-15  79.57  79.8600  79.12  79.57  5049473.0       0.0    1.0
# 2018-08-16  79.90  80.6100  79.80  80.05  5456218.0       0.0    1.0
# 2018-08-17  80.04  80.4353  79.68  79.75  9001373.0       0.0    1.0
# 2018-08-20  81.52  82.4200  80.95  82.18  9343021.0       0.0    1.0
# 2018-08-21  82.31  83.0750  82.02  82.95  6336959.0       0.0    1.0
# 2018-08-22  83.10  83.6800  82.28  82.64  4308340.0       0.0    1.0
# 2018-08-23  82.43  83.5700  82.34  82.91  4156852.0       0.0    1.0
# 2018-08-24  82.42  82.8793  82.10  82.45  3452989.0       0.0    1.0
# 2018-08-27  83.04  83.4500  82.23  82.65  4012426.0       0.0    1.0
# 2018-08-28  83.23  83.6300  82.48  82.58  3788811.0       0.0    1.0
#
#             Adj_Open  Adj_High  Adj_Low  Adj_Close  Adj_Volume
# Date
# 2018-08-15     79.57   79.8600    79.12      79.57   5049473.0
# 2018-08-16     79.90   80.6100    79.80      80.05   5456218.0
# ...

# %%
stock = pd.DataFrame(Stock)

# %%
#stock['Fortnight'] = stock.Close.rolling(14).mean()      #'rolling' method computes moving averages
#stock['Month'] = stock.Close.rolling(28).mean()

# %%
plt.figure(figsize = (15, 10))
plt.grid(True)
plt.plot(stock['Close'], label = 'NIKE', color = 'g')
plt.ylabel('Stock Price')
plt.xlabel('Year')
#plt.plot(stock['Fortnight'], label = '2 Week Average')
#plt.plot(stock['Month'], label = 'Monthly Average')
plt.title('Average Closing Price of Nike Inc. Since IPO')
plt.legend(loc = 1)
plt.show()

# %%
stock2 = Stock.tail(126)

# %%
stock2
# Out:
# Date
# 2018-03-01    66.32
# 2018-03-02    65.89
# 2018-03-05    65.05
# 2018-03-06    65.24
# 2018-03-07    64.17
# 2018-03-08    65.11
# 2018-03-09    66.30
# 2018-03-12    66.82
# 2018-03-13    66.17
# 2018-03-14    66.20
# 2018-03-15    66.39
# 2018-03-16    65.91
# 2018-03-19    65.71
# 2018-03-20    66.80
# 2018-03-21    66.35
# 2018-03-22    64.42
# 2018-03-23    64.63
# 2018-03-26    65.90
# 2018-03-27    66.17
# 2018-03-28    65.44
# 2018-03-29    66.44
# 2018-04-02    64.12
# 2018-04-03    66.70
# 2018-04-04    68.42
# 2018-04-05    69.59
# 2018-04-06    67.55
# 2018-04-09    67.18
# 2018-04-10    67.00
# 2018-04-11    66.83
# 2018-04-12    67.77
#               ...
# 2018-07-18    76.59
# 2018-07-19    76.95
# 2018-07-20    76.96
# 2018-07-23    76.59
# 2018-07-24    75.53
# 2018-07-25    77.16
# 2018-07-26    78.15
# 2018-07-27    76.89
# 2018-07-30    75.96
# 2018-07-31    76.91
# 2018-08-01    77.54
# 2018-08-02    78.65
# 2018-08-03    78.74
# 2018-08-06    79.51
# ...

# %%
print(max(stock2))
# Out:
# 82.95

# %%
print(min(stock2))
# Out:
# 64.12

# %%
stock['Six Months'] = stock.Close.rolling(126).mean()      #'rolling' method computes moving averages
stock['Three Months'] = stock.Close.rolling(75).mean()

# %%
start = '2018-1-1'
start
# Out:
# '2018-1-1'

# %%
end = '2018-8-24'
end
# Out:
# '2018-8-24'

# %%
#plt.figure(figsize = (15, 10))
#plt.grid(True)
#plt.plot(stock['Close'], label = 'NIKE', color = 'b')
#plt.ylabel('Stock Price')
#plt.xlabel('Year')
#plt.plot(stock['Fortnight'], label = '2 Week Average')
#plt.plot(stock['Month'], label = 'Monthly Average')
#plt.title('Average Closing Price of Nike Inc. Since IPO')
#plt.legend(loc = 2)
#plt.show()
