# %%
import pandas as pd
df = pd.read_csv('data.csv', 'r') 
df
# Out:
#            Jah  ,Umsatz
# 0   2010,12345      NaN
# 1   2011,12500      NaN
# 2    2012,8000      NaN
# 3   2013,15000      NaN
# 4   2014,18000      NaN
# 5    2015,5000      NaN
# 6    2016,8000      NaN
# 7   2017,12345      NaN
# 8   2018,10000      NaN
# 9    2019,7000      NaN
# 10  2020,16000      NaN

# %%
df.head()
# Out:
#           Jah  ,Umsatz
# 0  2010,12345      NaN
# 1  2011,12500      NaN
# 2   2012,8000      NaN
# 3  2013,15000      NaN
# 4  2014,18000      NaN

# %%
df.head(2)
# Out:
#           Jah  ,Umsatz
# 0  2010,12345      NaN
# 1  2011,12500      NaN

# %%
df.tail()
# Out:
#            Jah  ,Umsatz
# 6    2016,8000      NaN
# 7   2017,12345      NaN
# 8   2018,10000      NaN
# 9    2019,7000      NaN
# 10  2020,16000      NaN

# %%
df.tail(2)
# Out:
#            Jah  ,Umsatz
# 9    2019,7000      NaN
# 10  2020,16000      NaN

# %%
df['Jah']
# Out:
# 0     2010,12345
# 1     2011,12500
# 2      2012,8000
# 3     2013,15000
# 4     2014,18000
# 5      2015,5000
# 6      2016,8000
# 7     2017,12345
# 8     2018,10000
# 9      2019,7000
# 10    2020,16000
# Name: Jah, dtype: object

# %%
example = df.iloc[5]
print(example['Jah'])
# Out:
# 2015,5000

# %%
len(df)
# Out:
# 11

# %%
df.iloc[2:6]                                               #Slicing can also be implemented
# Out:
#           Jah
# 2   2012,8000
# 3  2013,15000
# 4  2014,18000
# 5   2015,5000

# %%
df.iloc[-5:]                                               #'-5:' gives the last 5 entries
# Out:
#            Jah
# 6    2016,8000
# 7   2017,12345
# 8   2018,10000
# 9    2019,7000
# 10  2020,16000

# %%
#Filtering data
df2 = pd.read_csv('EOD-INTC.csv')
df2.head()
# Out:
#          Date   Open   High    Low  Close      Volume  Dividend  Split  \
# 0  2018-08-27  48.00  48.39  47.63  48.35  17170257.0       0.0    1.0
# 1  2018-08-24  47.29  47.89  47.08  47.66  18214708.0       0.0    1.0
# 2  2018-08-23  46.86  47.17  46.71  46.98  31343206.0       0.0    1.0
# 3  2018-08-22  47.25  47.35  46.92  47.05  23182485.0       0.0    1.0
# 4  2018-08-21  46.66  47.85  46.64  47.62  19254336.0       0.0    1.0
#
#    Adj_Open  Adj_High  Adj_Low  Adj_Close  Adj_Volume
# 0     48.00     48.39    47.63      48.35  17170257.0
# 1     47.29     47.89    47.08      47.66  18214708.0
# 2     46.86     47.17    46.71      46.98  31343206.0
# 3     47.25     47.35    46.92      47.05  23182485.0
# 4     46.66     47.85    46.64      47.62  19254336.0

# %%
df3= ex.iloc[2]
df3
# Out:
# Date           2018-08-23
# Open                46.86
# High                47.17
# Low                 46.71
# Close               46.98
# Volume        3.13432e+07
# Dividend                0
# Split                   1
# Adj_Open            46.86
# Adj_High            47.17
# Adj_Low             46.71
# Adj_Close           46.98
# Adj_Volume    3.13432e+07
# Name: 2, dtype: object

# %%
df3.loc['Close']
# Out:
# 46.98

# %%
for row in df2.iterrows():
    print(row)
    break
# Out:
# (0, Date           2018-08-27
# Open                   48
# High                48.39
# Low                 47.63
# Close               48.35
# Volume        1.71703e+07
# Dividend                0
# Split                   1
# Adj_Open               48
# Adj_High            48.39
# Adj_Low             47.63
# Adj_Close           48.35
# Adj_Volume    1.71703e+07
# Name: 0, dtype: object)

# %%
for row in df2.iterrows():
    pos = row[0]
    d = row[1]
    print(pos)
    print(d)
    break
# Out:
# 0
# Date           2018-08-27
# Open                   48
# High                48.39
# Low                 47.63
# Close               48.35
# Volume        1.71703e+07
# Dividend                0
# Split                   1
# Adj_Open               48
# Adj_High            48.39
# Adj_Low             47.63
# Adj_Close           48.35
# Adj_Volume    1.71703e+07
# Name: 0, dtype: object

# %%
for row in df2.iterrows():
    pos, d = row
    print(pos)
    print(d)
    break
# Out:
# 0
# Date           2018-08-27
# Open                   48
# High                48.39
# Low                 47.63
# Close               48.35
# Volume        1.71703e+07
# Dividend                0
# Split                   1
# Adj_Open               48
# Adj_High            48.39
# Adj_Low             47.63
# Adj_Close           48.35
# Adj_Volume    1.71703e+07
# Name: 0, dtype: object

# %%
for pos, d in df2.iterrows():                                                #Removes '0' from above (index)
    print(d)
    break
# Out:
# Date           2018-08-27
# Open                   48
# High                48.39
# Low                 47.63
# Close               48.35
# Volume        1.71703e+07
# Dividend                0
# Split                   1
# Adj_Open               48
# Adj_High            48.39
# Adj_Low             47.63
# Adj_Close           48.35
# Adj_Volume    1.71703e+07
# Name: 0, dtype: object

# %%
for pos, d in df2.iterrows():                                                #Removes '0' from above (index)
    print(d['Close'])
    break
# Out:
# 48.35

# %%
for pos, d in df2.iterrows():                                               
    print(d['Close'])
# Out:
# 48.35
# 47.66
# 46.98
# 47.05
# 47.62
# 46.5
# 47.1
# 47.17
# 47.46
# 48.12
# 48.45
# 48.85
# 50.14
# 49.96
# 49.7
# 49.3
# 49.63
# 49.48
# 48.81
# 48.1
# 47.69
# 47.68
# 52.16
# 52.43
# 52.18
# 52.31
# 51.91
# 51.98
# 51.72
# 51.75
# 52.01
# 52.22
# 52.35
# 51.2
# 52.16
# 51.86
# 51.37
# 50.75
# 49.47
# 50.2
# 49.71
# 49.25
# 48.76
# 49.67
# 50.71
# 52.5
# 52.19
# 53.46
# 52.93
# 53.22
# 55.11
# 55.54
# 55.03
# 54.82
# 54.52
# 55.05
# 55.88
# 57.03
# 56.53
# 56.83
# 57.08
# 55.2
# 55.68
# 55.32
# 55.44
# 54.75
# 55.21
# 54.45
# 54.32
# 53.5
# 54.81
# 54.64
# 53.92
# 54.9
# 54.67
# 54.98
# 54.34
# 53.63
# 53.33
# 52.78
# 52.28
# 52.31
# 53.33
# 51.62
# 52.73
# 53.05
# 51.38
# 51.45
# 51.1
# 51.53
# 52.22
# 53.61
# 53.54
# 52.4
# 51.86
# 52.72
# 51.1
# 51.27
# 49.55
# 48.79
# 50.38
# 49.99
# 49.75
# 48.92
# 52.08
# 49.6
# 51.19
# 52.48
# 49.36
# 50.83
# 51.56
# 51.55
# 50.83
# 51.17
# 50.88
# 51.86
# 51.78
# 51.52
# 52.19
# 50.74
# 51.32
# 50.71
# 49.75
# 48.98
# 47.84
# 49.29
# ...

# %%
df2['Close'] >= 100.00
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 9667    False
# 9668    False
# 9669    False
# 9670    False
# 9671    False
# 9672    False
# 9673    False
# 9674    False
# 9675    False
# 9676    False
# 9677    False
# 9678    False
# 9679    False
# 9680    False
# 9681    False
# 9682    False
# 9683    False
# 9684    False
# 9685    False
# 9686    False
# 9687    False
# 9688    False
# 9689    False
# 9690    False
# 9691    False
# 9692    False
# 9693    False
# 9694    False
# 9695    False
# 9696    False
# ...

# %%
df2[df2['Close'] >= 100.00]                                   #Can be saved by assigning data to a variable
# Out:
#             Date    Open    High     Low   Close      Volume  Dividend  Split  \
# 4548  2000-07-28  138.00  139.40  128.80  129.10  27716900.0       0.0    1.0
# 4549  2000-07-27  138.50  140.40  136.00  137.00  19611900.0       0.0    1.0
